# %%
import os
import re
from neo4j import GraphDatabase

# Function to parse a single .abs file
def parse_abs_data(abs_data):
    patterns = {
        'paper_id': r'Paper: (.+)',
        'authors': r'Authors: (.+)',
        'title': r'Title: (.+)',
        'comments': r'Comments: (.+)',
        'subj_class': r'Subj-class: (.+)',
        'journal_ref': r'Journal-ref: (.+)',
        'abstract': r'\n\\\\\n ([\s\S]+?)\n\\\\\n',
    }
    return {key: re.search(pattern, abs_data).group(1).strip() if re.search(pattern, abs_data) else None
            for key, pattern in patterns.items()}

# Neo4j uploader class
class Neo4jUploader:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def delete_all_papers(self):
        """Delete all existing Paper nodes in the database."""
        with self.driver.session() as session:
            session.write_transaction(self._delete_all_papers)

    @staticmethod
    def _delete_all_papers(tx):
        query = "MATCH (p:Paper) DETACH DELETE p"
        tx.run(query)
        print("All existing Paper nodes deleted.")

    def create_paper_node(self, parsed_data):
        with self.driver.session() as session:
            session.write_transaction(self._create_and_return_paper, parsed_data)

    @staticmethod
    def _create_and_return_paper(tx, parsed_data):
        query = """
        MERGE (p:Paper {paper_id: $paper_id})
        SET p.title = $title,
            p.authors = $authors,
            p.comments = $comments,
            p.subj_class = $subj_class,
            p.journal_ref = $journal_ref,
            p.abstract = $abstract
        """
        tx.run(query, 
               paper_id=parsed_data.get('paper_id'), 
               title=parsed_data.get('title'), 
               authors=parsed_data.get('authors'), 
               comments=parsed_data.get('comments'), 
               subj_class=parsed_data.get('subj_class'), 
               journal_ref=parsed_data.get('journal_ref'), 
               abstract=parsed_data.get('abstract'))

    def create_citation_edge(self, from_node, to_node):
        with self.driver.session() as session:
            session.write_transaction(self._create_citation_if_not_exists, from_node, to_node)

    @staticmethod
    def _create_citation_if_not_exists(tx, from_node, to_node):
        # Only create the edge if it doesn't already exist
        query = """
        MATCH (a:Paper {paper_id: $from_node})
        MATCH (b:Paper {paper_id: $to_node})
        MERGE (a)-[:CITES]->(b)
        """
        tx.run(query, from_node=from_node, to_node=to_node)

# Function to process all .abs files and create nodes
def process_all_abs_files(root_folder, neo4j_uploader):
    for year_folder in os.listdir(root_folder):
        year_path = os.path.join(root_folder, year_folder)
        if os.path.isdir(year_path) and year_folder.isdigit():
            for file_name in os.listdir(year_path):
                if file_name.endswith(".abs"):
                    file_path = os.path.join(year_path, file_name)
                    with open(file_path, 'r', encoding='utf-8') as file:
                        abs_data = file.read()
                        parsed_data = parse_abs_data(abs_data)
                        # Remove leading zeros from filename
                        parsed_data['paper_id'] = str(int(file_name.replace('.abs', '')))
                        neo4j_uploader.create_paper_node(parsed_data)
                        print(f"Uploaded: {parsed_data['paper_id']}")

# Function to read and parse Cit-HepTh.txt and create edges in Neo4j with progress tracking
def create_edges_from_file(file_path, neo4j_uploader, last_processed_edge=0):
    current_edge = 0
    with open(file_path, 'r') as file:
        for line in file:
            if line.startswith("#"):
                continue
            current_edge += 1
            # Skip edges already processed
            if current_edge <= last_processed_edge:
                continue

            from_node, to_node = line.strip().split()
            neo4j_uploader.create_citation_edge(from_node, to_node)
            print(f"Created edge: {from_node} -> {to_node}")

            # Save the progress every 1000 edges to avoid starting over completely if interrupted
            if current_edge % 1000 == 0:
                with open("last_processed_edge.txt", "w") as progress_file:
                    progress_file.write(str(current_edge))

    # Save the final progress
    with open("last_processed_edge.txt", "w") as progress_file:
        progress_file.write(str(current_edge))

# Helper function to load the last processed edge from file
def load_last_processed_edge():
    try:
        with open("last_processed_edge.txt", "r") as file:
            return int(file.read().strip())
    except FileNotFoundError:
        return 0

# Usage
# root_folder = "/Users/ericweng/Git/CS6400-project/abstract"
neo4j_uploader = Neo4jUploader("neo4j+s://849cda2b.databases.neo4j.io", "neo4j", "4-lyw_1kBYJo9ICwtV_64qFskgvpvgE6A9pwL6aeQ4U")

# Delete existing nodes, then upload new nodes and edges
# neo4j_uploader.delete_all_papers()
# process_all_abs_files(root_folder, neo4j_uploader)

# Load the last processed edge to continue from where it left off
# last_processed_edge = load_last_processed_edge()
create_edges_from_file("/nethome/xweng42/CS6400/cit-HepTh.txt", neo4j_uploader, 235329)

neo4j_uploader.close()
print("All nodes and edges uploaded successfully.")
# Out:
# /tmp/ipykernel_2652202/3029698462.py:65: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(self._create_citation_if_not_exists, from_node, to_node)
# Created edge: 202052 -> 105052
# Created edge: 202052 -> 105070
# Created edge: 202052 -> 105093
# Created edge: 202052 -> 105117
# Created edge: 202052 -> 105214
# Created edge: 202052 -> 105249
# Created edge: 202052 -> 106113
# Created edge: 202052 -> 107238
# Created edge: 202052 -> 110007
# Created edge: 202052 -> 110265
# Created edge: 202052 -> 111008
# Created edge: 202052 -> 111093
# Created edge: 202052 -> 111182
# Created edge: 202052 -> 111238
# Created edge: 202052 -> 112253
# Created edge: 202052 -> 201247
# Created edge: 202052 -> 9204046
# Created edge: 202052 -> 9207016
# Created edge: 202052 -> 9402002
# Created edge: 202052 -> 9411187
# Created edge: 202052 -> 9812013
# Created edge: 202053 -> 104188
# Created edge: 202053 -> 108058
# Created edge: 202053 -> 111190
# Created edge: 202053 -> 9208029
# Created edge: 202053 -> 9211121
# Created edge: 202053 -> 9312062
# Created edge: 202053 -> 9403195
# Created edge: 202053 -> 9407087
# Created edge: 202053 -> 9408074
# Created edge: 202053 -> 9408099
# Created edge: 202053 -> 9411102
# Created edge: 202053 -> 9411205
# Created edge: 202053 -> 9411210
# Created edge: 202053 -> 9502047
# Created edge: 202053 -> 9503201
# Created edge: 202053 -> 9504006
# Created edge: 202053 -> 9506002
# Created edge: 202053 -> 9511222
# Created edge: 202053 -> 9612143
# Created edge: 202053 -> 9703136
# Created edge: 202053 -> 9706225
# Created edge: 202053 -> 9707118
# Created edge: 202053 -> 9907123
# Created edge: 9411205 -> 9204035
# Created edge: 9411205 -> 9208029
# Created edge: 9411205 -> 9211121
# Created edge: 9411205 -> 9306080
# Created edge: 9411205 -> 9407023
# Created edge: 9411205 -> 9407087
# Created edge: 9411205 -> 9408013
# Created edge: 9411205 -> 9411048
# Created edge: 9411205 -> 9411049
# Created edge: 9411205 -> 9411057
# Created edge: 9411205 -> 9411102
# Created edge: 202054 -> 9195
# Created edge: 202054 -> 103038
# Created edge: 202054 -> 106227
# Created edge: 202054 -> 108129
# Created edge: 202054 -> 110080
# Created edge: 202054 -> 9508114
# Created edge: 202054 -> 9804192
# Created edge: 202055 -> 1193
# Created edge: 202055 -> 3188
# Created edge: 202055 -> 5053
# Created edge: 202055 -> 5280
# Created edge: 202055 -> 105309
# Created edge: 202055 -> 112146
# Created edge: 202055 -> 112258
# Created edge: 202055 -> 9303139
# Created edge: 202055 -> 9502091
# Created edge: 202055 -> 9711002
# Created edge: 202055 -> 9711200
# Created edge: 202055 -> 9802109
# Created edge: 202055 -> 9802150
# Created edge: 202055 -> 9806217
# Created edge: 202055 -> 9807226
# Created edge: 202055 -> 9905104
# Created edge: 202055 -> 9912092
# Created edge: 202056 -> 7191
# Created edge: 202056 -> 8001
# Created edge: 202056 -> 9156
# Created edge: 202056 -> 11077
# Created edge: 202056 -> 11193
# Created edge: 202056 -> 103163
# Created edge: 202056 -> 106014
# Created edge: 202056 -> 107057
# Created edge: 202056 -> 108101
# Created edge: 202056 -> 111060
# Created edge: 202056 -> 112119
# Created edge: 202056 -> 9603167
# Created edge: 202056 -> 9610205
# Created edge: 202056 -> 9711200
# Created edge: 202056 -> 9802109
# Created edge: 202056 -> 9802150
# Created edge: 202056 -> 9806087
# Created edge: 202056 -> 9807080
# Created edge: 202056 -> 9808075
# Created edge: 202056 -> 9905226
# Created edge: 202056 -> 9907216
# Created edge: 202056 -> 9911042
# Created edge: 202056 -> 9911096
# Created edge: 202057 -> 5251
# Created edge: 202057 -> 105204
# Created edge: 202057 -> 106079
# Created edge: 202057 -> 107116
# Created edge: 202057 -> 107159
# Created edge: 202057 -> 108075
# Created edge: 202057 -> 108135
# Created edge: 202057 -> 108183
# Created edge: 202057 -> 111154
# Created edge: 202057 -> 111155
# Created edge: 202057 -> 111212
# Created edge: 202057 -> 112101
# Created edge: 202057 -> 201132
# Created edge: 202057 -> 9207111
# Created edge: 202057 -> 9304104
# Created edge: 202057 -> 9506071
# Created edge: 202057 -> 9508068
# Created edge: 202057 -> 9508098
# Created edge: 202057 -> 9509115
# Created edge: 202057 -> 9706158
# Created edge: 202057 -> 9707148
# Created edge: 202057 -> 9707160
# Created edge: 202057 -> 9802183
# Created edge: 202057 -> 9807076
# Created edge: 202057 -> 9807213
# Created edge: 202057 -> 9808095
# Created edge: 202057 -> 9903028
# Created edge: 202057 -> 9906101
# Created edge: 202057 -> 9906234
# Created edge: 202057 -> 9909109
# Created edge: 202057 -> 9912144
# Created edge: 9508098 -> 9206042
# Created edge: 9508098 -> 9310178
# Created edge: 9508098 -> 9312066
# Created edge: 202058 -> 9701093
# Created edge: 202058 -> 9808061
# Created edge: 202058 -> 9905050
# Created edge: 202059 -> 1048
# Created edge: 202059 -> 9705006
# Created edge: 202059 -> 9707128
# Created edge: 202059 -> 9809019
# Created edge: 202060 -> 4005
# Created edge: 202060 -> 4124
# Created edge: 202060 -> 4166
# Created edge: 202060 -> 8074
# Created edge: 202060 -> 8160
# Created edge: 202060 -> 9122
# Created edge: 202060 -> 10093
# Created edge: 202060 -> 101060
# Created edge: 202060 -> 101160
# Created edge: 202060 -> 104226
# Created edge: 202060 -> 104227
# Created edge: 202060 -> 105100
# Created edge: 202060 -> 106203
# Created edge: 202060 -> 107233
# Created edge: 202060 -> 108172
# Created edge: 202060 -> 108194
# Created edge: 202060 -> 109122
# Created edge: 202060 -> 109133
# Created edge: 202060 -> 110143
# Created edge: 202060 -> 112227
# Created edge: 202060 -> 201066
# Created edge: 202060 -> 9510209
# Created edge: 202060 -> 9603142
# Created edge: 202060 -> 9905012
# Created edge: 202060 -> 9906064
# Created edge: 202060 -> 9910149
# Created edge: 202060 -> 9910219
# Created edge: 202060 -> 9912287
# Created edge: 202062 -> 7046
# Created edge: 202062 -> 11172
# Created edge: 202062 -> 103074
# Created edge: 202062 -> 104224
# Created edge: 202062 -> 105303
# Created edge: 202062 -> 109186
# Created edge: 202062 -> 110057
# Created edge: 202062 -> 110114
# Created edge: 202062 -> 111267
# Created edge: 202062 -> 9711183
# Created edge: 202063 -> 5036
# Created edge: 202063 -> 5209
# Created edge: 202063 -> 5212
# Created edge: 202063 -> 104102
# Created edge: 202063 -> 109033
# Created edge: 202063 -> 110167
# Created edge: 202063 -> 9311009
# Created edge: 202063 -> 9411099
# Created edge: 202063 -> 9412106
# Created edge: 202063 -> 9502038
# Created edge: 202063 -> 9505052
# Created edge: 202063 -> 9705099
# Created edge: 202063 -> 9902127
# Created edge: 202063 -> 9912249
# Created edge: 202064 -> 6025
# Created edge: 202064 -> 6027
# Created edge: 202064 -> 8240
# Created edge: 202064 -> 10088
# Created edge: 202064 -> 10272
# Created edge: 202064 -> 11089
# Created edge: 202064 -> 11256
# Created edge: 202064 -> 12011
# Created edge: 202064 -> 101043
# Created edge: 202064 -> 102185
# Created edge: 202064 -> 103155
# Created edge: 202064 -> 104184
# Created edge: 202064 -> 104208
# Created edge: 202064 -> 107100
# Created edge: 202064 -> 107177
# Created edge: 202064 -> 108084
# Created edge: 202064 -> 108226
# Created edge: 202064 -> 108245
# Created edge: 202064 -> 110216
# Created edge: 202064 -> 111097
# Created edge: 202064 -> 111198
# Created edge: 202064 -> 9805038
# Created edge: 202064 -> 9808147
# Created edge: 202064 -> 9910075
# Created edge: 202064 -> 9911042
# Created edge: 202064 -> 9911139
# Created edge: 202064 -> 9911225
# Created edge: 202064 -> 9912266
# Created edge: 202065 -> 2186
# Created edge: 202065 -> 3006
# Created edge: 202065 -> 3160
# Created edge: 202065 -> 3208
# Created edge: 202065 -> 4062
# Created edge: 202065 -> 5031
# Created edge: 202065 -> 5101
# Created edge: 202065 -> 5156
# Created edge: 202065 -> 5272
# Created edge: 202065 -> 7043
# Created edge: 202065 -> 7127
# Created edge: 202065 -> 7160
# Created edge: 202065 -> 7217
# Created edge: 202065 -> 8013
# Created edge: 202065 -> 9142
# Created edge: 202065 -> 10060
# Created edge: 202065 -> 10264
# Created edge: 202065 -> 12262
# Created edge: 202065 -> 102044
# Created edge: 202065 -> 102181
# Created edge: 202065 -> 104076
# Created edge: 202065 -> 104153
# Created edge: 202065 -> 107033
# Created edge: 202065 -> 107225
# Created edge: 202065 -> 110093
# Created edge: 202065 -> 9208027
# Created edge: 202065 -> 9503124
# Created edge: 202065 -> 9601092
# Created edge: 202065 -> 9607201
# Created edge: 202065 -> 9610043
# Created edge: 202065 -> 9611233
# Created edge: 202065 -> 9612115
# Created edge: 202065 -> 9612192
# Created edge: 202065 -> 9702201
# Created edge: 202065 -> 9708130
# Created edge: 202065 -> 9711162
# Created edge: 202065 -> 9712201
# Created edge: 202065 -> 9801132
# Created edge: 202065 -> 9802051
# Created edge: 202065 -> 9802085
# Created edge: 202065 -> 9804199
# Created edge: 202065 -> 9805034
# Created edge: 202065 -> 9812208
# Created edge: 202065 -> 9812219
# Created edge: 202065 -> 9903187
# Created edge: 202065 -> 9908038
# Created edge: 202065 -> 9908141
# Created edge: 202065 -> 9908142
# Created edge: 202065 -> 9909139
# Created edge: 202065 -> 9912072
# Created edge: 202066 -> 8129
# Created edge: 202066 -> 101229
# Created edge: 202066 -> 9408099
# Created edge: 202066 -> 9504139
# Created edge: 202066 -> 9506035
# Created edge: 202066 -> 9509141
# Created edge: 202066 -> 9704102
# Created edge: 202066 -> 9709109
# Created edge: 202066 -> 9908105
# Created edge: 202066 -> 9911174
# Created edge: 202067 -> 106105
# Created edge: 202067 -> 106123
# Created edge: 202067 -> 108236
# Created edge: 202067 -> 201239
# Created edge: 202067 -> 9506135
# Created edge: 202067 -> 9510175
# Created edge: 202067 -> 9601078
# Created edge: 202067 -> 9603097
# Created edge: 202067 -> 9607036
# Created edge: 202067 -> 9812110
# Created edge: 202067 -> 9902132
# Created edge: 202067 -> 9908036
# Created edge: 202068 -> 12264
# Created edge: 202068 -> 101105
# Created edge: 202068 -> 9503023
# Created edge: 202068 -> 9608070
# Created edge: 202068 -> 9608071
# Created edge: 202068 -> 9811015
# Created edge: 202069 -> 4061
# Created edge: 202069 -> 5040
# Created edge: 202069 -> 5247
# Created edge: 202069 -> 111161
# Created edge: 202069 -> 111210
# Created edge: 202069 -> 9603089
# Created edge: 202069 -> 9606112
# Created edge: 202069 -> 9607051
# Created edge: 202070 -> 9811222
# Created edge: 9811222 -> 9707221
# Created edge: 202071 -> 3249
# Created edge: 202071 -> 11106
# Created edge: 202071 -> 101120
# Created edge: 202071 -> 106193
# Created edge: 202071 -> 112151
# Created edge: 202071 -> 9306013
# Created edge: 202071 -> 9307111
# Created edge: 202071 -> 9311015
# Created edge: 202071 -> 9504150
# Created edge: 202071 -> 9803027
# Created edge: 202071 -> 9803170
# Created edge: 202071 -> 9806133
# Created edge: 202071 -> 9808120
# Created edge: 202071 -> 9809165
# Created edge: 202071 -> 9811083
# Created edge: 202071 -> 9904027
# Created edge: 202071 -> 9906087
# Created edge: 202071 -> 9911243
# Created edge: 202072 -> 105136
# Created edge: 202072 -> 107113
# Created edge: 202072 -> 109154
# Created edge: 202072 -> 9504147
# Created edge: 202072 -> 9506200
# Created edge: 202072 -> 9510134
# Created edge: 202072 -> 9511053
# Created edge: 202072 -> 9601029
# Created edge: 202072 -> 9602043
# Created edge: 202072 -> 9711200
# Created edge: 202073 -> 2256
# Created edge: 202073 -> 9185
# Created edge: 202073 -> 106113
# Created edge: 202073 -> 110031
# Created edge: 202073 -> 9203050
# Created edge: 202073 -> 9205030
# Created edge: 202073 -> 9304068
# Created edge: 202073 -> 9401110
# Created edge: 202073 -> 9409089
# Created edge: 202073 -> 9410041
# Created edge: 202073 -> 9711200
# Created edge: 202073 -> 9802150
# Created edge: 202073 -> 9804177
# Created edge: 202073 -> 9809027
# Created edge: 202073 -> 9810251
# Created edge: 202073 -> 9812034
# Created edge: 202073 -> 9902040
# Created edge: 202073 -> 9910065
# Created edge: 202074 -> 5029
# Created edge: 202074 -> 11060
# Created edge: 202074 -> 101143
# Created edge: 202074 -> 108102
# Created edge: 202074 -> 108238
# Created edge: 202074 -> 109021
# Created edge: 202074 -> 201113
# Created edge: 202074 -> 9410029
# Created edge: 202074 -> 9510017
# Created edge: 202074 -> 9601038
# Created edge: 202074 -> 9603167
# Created edge: 202074 -> 9806155
# Created edge: 202074 -> 9905024
# Created edge: 202074 -> 9905078
# Created edge: 202074 -> 9906242
# Created edge: 202074 -> 9907007
# Created edge: 202074 -> 9908025
# Created edge: 202074 -> 9909072
# Created edge: 202074 -> 9910109
# Created edge: 202075 -> 2159
# Created edge: 202075 -> 7191
# Created edge: 202075 -> 8001
# Created edge: 202075 -> 9211
# Created edge: 202075 -> 10010
# Created edge: 202075 -> 10088
# Created edge: 202075 -> 11023
# Created edge: 202075 -> 12011
# Created edge: 202075 -> 101020
# Created edge: 202075 -> 101096
# Created edge: 202075 -> 102185
# Created edge: 202075 -> 103155
# Created edge: 202075 -> 106162
# Created edge: 202075 -> 106186
# Created edge: 202075 -> 9305143
# Created edge: 202075 -> 9603087
# Created edge: 202075 -> 9604035
# Created edge: 202075 -> 9604168
# Created edge: 202075 -> 9604179
# Created edge: 202075 -> 9707176
# Created edge: 202075 -> 9801049
# Created edge: 202075 -> 9801165
# Created edge: 202075 -> 9803061
# Created edge: 202075 -> 9807173
# Created edge: 202075 -> 9909184
# Created edge: 202076 -> 4036
# Created edge: 202076 -> 102061
# Created edge: 202076 -> 107045
# Created edge: 202076 -> 9811052
# Created edge: 204224 -> 109185
# Created edge: 204224 -> 9601025
# Created edge: 204224 -> 9609193
# Created edge: 204224 -> 9806006
# Created edge: 204224 -> 9906113
# Created edge: 9801101 -> 9307011
# Created edge: 9801101 -> 9311111
# Created edge: 9801101 -> 9412017
# Created edge: 9801101 -> 9503117
# Created edge: 9801101 -> 9602013
# Created edge: 9806006 -> 9409068
# Created edge: 9806006 -> 9601025
# Created edge: 9806006 -> 9609193
# Created edge: 202078 -> 5142
# Created edge: 202078 -> 5214
# Created edge: 202078 -> 101039
# Created edge: 202078 -> 104154
# Created edge: 202078 -> 108197
# Created edge: 202078 -> 9411224
# Created edge: 202078 -> 9510135
# Created edge: 202078 -> 9802096
# Created edge: 202078 -> 9805128
# Created edge: 202078 -> 9810072
# Created edge: 202078 -> 9812219
# Created edge: 202078 -> 9905065
# Created edge: 202078 -> 9906161
# Created edge: 202078 -> 9906192
# Created edge: 202078 -> 9907055
# Created edge: 202078 -> 9908056
# Created edge: 202078 -> 9908142
# Created edge: 202078 -> 9911085
# Created edge: 202078 -> 9911140
# Created edge: 202079 -> 8227
# Created edge: 202079 -> 8231
# Created edge: 202079 -> 9103
# Created edge: 202079 -> 9148
# Created edge: 202079 -> 9191
# Created edge: 202079 -> 9246
# Created edge: 202079 -> 10108
# Created edge: 202079 -> 10218
# Created edge: 202079 -> 11002
# Created edge: 202079 -> 11033
# Created edge: 202079 -> 11226
# Created edge: 202079 -> 12080
# Created edge: 202079 -> 12198
# Created edge: 202079 -> 12210
# Created edge: 202079 -> 101002
# Created edge: 202079 -> 102173
# Created edge: 202079 -> 102174
# Created edge: 202079 -> 103089
# Created edge: 202079 -> 103102
# Created edge: 202079 -> 106103
# Created edge: 202079 -> 9208027
# Created edge: 202079 -> 9210065
# Created edge: 202079 -> 9303067
# Created edge: 202079 -> 9303143
# Created edge: 202079 -> 9311177
# Created edge: 202079 -> 9709027
# Created edge: 202079 -> 9805170
# Created edge: 202079 -> 9902105
# Created edge: 202079 -> 9904207
# Created edge: 202079 -> 9911116
# Created edge: 202080 -> 102039
# Created edge: 202080 -> 103190
# Created edge: 202080 -> 105164
# Created edge: 202080 -> 9202057
# Created edge: 202080 -> 9206046
# Created edge: 202080 -> 9210109
# Created edge: 202080 -> 9304047
# Created edge: 202080 -> 9310095
# Created edge: 202080 -> 9411054
# Created edge: 202080 -> 9412124
# Created edge: 202080 -> 9602107
# Created edge: 202080 -> 9709053
# Created edge: 202080 -> 9810211
# Created edge: 202081 -> 3049
# Created edge: 202081 -> 3140
# Created edge: 202081 -> 5254
# Created edge: 202081 -> 103014
# Created edge: 202081 -> 111186
# Created edge: 202081 -> 9709165
# Created edge: 202081 -> 9903101
# Created edge: 202082 -> 107239
# Created edge: 202082 -> 108101
# Created edge: 202082 -> 9302085
# Created edge: 202082 -> 9303044
# Created edge: 202082 -> 9604114
# Created edge: 202082 -> 9605162
# Created edge: 202082 -> 9705189
# Created edge: 202082 -> 9707133
# Created edge: 202082 -> 9709067
# Created edge: 202082 -> 9808071
# Created edge: 202082 -> 9906049
# Created edge: 9302085 -> 9503230
# Created edge: 202083 -> 2044
# Created edge: 202083 -> 8140
# Created edge: 202083 -> 8241
# Created edge: 202083 -> 101076
# Created edge: 202083 -> 102042
# Created edge: 202083 -> 102113
# Created edge: 202083 -> 104141
# Created edge: 202083 -> 106113
# Created edge: 202083 -> 106201
# Created edge: 202083 -> 107169
# Created edge: 202083 -> 108167
# Created edge: 202083 -> 110007
# Created edge: 202083 -> 110108
# Created edge: 202083 -> 110265
# Created edge: 202083 -> 112093
# Created edge: 202083 -> 112226
# Created edge: 202083 -> 201174
# Created edge: 202083 -> 201176
# Created edge: 202083 -> 201210
# Created edge: 202083 -> 201215
# Created edge: 202083 -> 201268
# Created edge: 202083 -> 202008
# Created edge: 202083 -> 202052
# Created edge: 202083 -> 9306069
# Created edge: 202083 -> 9308139
# Created edge: 202083 -> 9309145
# Created edge: 202083 -> 9409089
# Created edge: 202083 -> 9504147
# Created edge: 202083 -> 9601029
# Created edge: 202083 -> 9605112
# Created edge: 202083 -> 9609075
# Created edge: 202083 -> 9610068
# Created edge: 202083 -> 9611175
# Created edge: 202083 -> 9612146
# Created edge: 202083 -> 9707170
# Created edge: 202083 -> 9711200
# Created edge: 202083 -> 9802109
# Created edge: 202083 -> 9802150
# Created edge: 202083 -> 9803131
# Created edge: 202083 -> 9805114
# Created edge: 202083 -> 9806026
# Created edge: 202083 -> 9812013
# Created edge: 202083 -> 9812056
# Created edge: 202083 -> 9901078
# Created edge: 202083 -> 9902121
# Created edge: 202083 -> 9905111
# Created edge: 202083 -> 9907030
# Created edge: 202084 -> 1112
# Created edge: 202084 -> 1133
# Created edge: 202084 -> 3256
# Created edge: 202084 -> 8008
# Created edge: 202084 -> 12104
# Created edge: 202084 -> 101049
# Created edge: 202084 -> 102046
# Created edge: 202084 -> 103239
# Created edge: 202084 -> 105199
# Created edge: 202084 -> 105212
# Created edge: 202084 -> 108187
# Created edge: 202084 -> 108220
# Created edge: 202084 -> 109050
# Created edge: 202084 -> 111030
# Created edge: 202084 -> 111098
# Created edge: 202084 -> 9507158
# Created edge: 202084 -> 9510209
# Created edge: 202084 -> 9602022
# Created edge: 202084 -> 9602114
# Created edge: 202084 -> 9603142
# Created edge: 202084 -> 9603161
# Created edge: 202084 -> 9605200
# Created edge: 202084 -> 9608195
# Created edge: 202084 -> 9610238
# Created edge: 202084 -> 9611204
# Created edge: 202084 -> 9701162
# Created edge: 202084 -> 9703007
# Created edge: 202084 -> 9705174
# Created edge: 202084 -> 9710208
# Created edge: 202084 -> 9711197
# Created edge: 202084 -> 9801057
# Created edge: 202084 -> 9801087
# Created edge: 202084 -> 9802202
# Created edge: 202084 -> 9803224
# Created edge: 202084 -> 9803235
# Created edge: 202084 -> 9806022
# Created edge: 202084 -> 9806051
# Created edge: 202084 -> 9808101
# Created edge: 202084 -> 9808159
# Created edge: 202084 -> 9811129
# Created edge: 202084 -> 9811168
# Created edge: 202084 -> 9812052
# Created edge: 202084 -> 9901009
# Created edge: 202084 -> 9901017
# Created edge: 202084 -> 9902071
# Created edge: 202084 -> 9904054
# Created edge: 202084 -> 9907026
# Created edge: 202084 -> 9907041
# Created edge: 202084 -> 9912208
# Created edge: 9811129 -> 9602022
# Created edge: 9811129 -> 9602114
# Created edge: 9811129 -> 9603161
# Created edge: 9811129 -> 9701162
# Created edge: 9811129 -> 9701165
# Created edge: 9811129 -> 9703007
# Created edge: 9811129 -> 9705174
# Created edge: 9811129 -> 9705197
# Created edge: 9811129 -> 9706093
# Created edge: 9811129 -> 9801057
# Created edge: 9811129 -> 9802194
# Created edge: 9811129 -> 9802202
# Created edge: 9811129 -> 9803224
# Created edge: 9811129 -> 9806094
# Created edge: 202085 -> 3243
# Created edge: 202085 -> 5110
# Created edge: 202085 -> 11089
# Created edge: 202085 -> 106064
# Created edge: 202085 -> 106066
# Created edge: 202085 -> 108203
# Created edge: 202085 -> 112200
# Created edge: 202085 -> 9409089
# Created edge: 202085 -> 9703129
# Created edge: 202085 -> 9901031
# Created edge: 202085 -> 9905179
# Created edge: 202086 -> 110095
# Created edge: 202087 -> 12145
# Created edge: 202087 -> 102076
# Created edge: 202087 -> 105059
# Created edge: 202087 -> 106048
# Created edge: 202087 -> 106157
# Created edge: 202087 -> 111034
# Created edge: 202087 -> 111069
# Created edge: 202087 -> 111087
# Created edge: 202087 -> 111129
# Created edge: 202087 -> 111281
# Created edge: 202087 -> 201015
# Created edge: 202087 -> 201136
# Created edge: 202087 -> 202030
# Created edge: 202087 -> 9705038
# Created edge: 202087 -> 9705241
# Created edge: 202087 -> 9908056
# Created edge: 202088 -> 1204
# Created edge: 202088 -> 2106
# Created edge: 202088 -> 5173
# Created edge: 202088 -> 9711002
# Created edge: 202088 -> 9711200
# Created edge: 202088 -> 9802109
# Created edge: 202088 -> 9802150
# Created edge: 202088 -> 9803002
# Created edge: 202088 -> 9805028
# Created edge: 202088 -> 9904191
# Created edge: 202088 -> 9905111
# Created edge: 202089 -> 107024
# Created edge: 202089 -> 9405143
# Created edge: 202089 -> 9603106
# Created edge: 202089 -> 9709213
# Created edge: 202090 -> 3025
# Created edge: 202090 -> 4092
# Created edge: 202090 -> 6117
# Created edge: 202090 -> 7012
# Created edge: 202090 -> 102095
# Created edge: 202090 -> 103098
# Created edge: 202090 -> 103183
# Created edge: 202090 -> 9407087
# Created edge: 202090 -> 9408099
# Created edge: 202090 -> 9411048
# Created edge: 202090 -> 9411057
# Created edge: 202090 -> 9504102
# Created edge: 202090 -> 9505075
# Created edge: 202090 -> 9505100
# Created edge: 202090 -> 9507008
# Created edge: 202090 -> 9509175
# Created edge: 202090 -> 9509176
# Created edge: 202090 -> 9607207
# Created edge: 202090 -> 9609145
# Created edge: 202090 -> 9611063
# Created edge: 202090 -> 9611230
# Created edge: 202090 -> 9612131
# Created edge: 202090 -> 9703166
# Created edge: 202090 -> 9703210
# Created edge: 202090 -> 9705031
# Created edge: 202090 -> 9705074
# Created edge: 202090 -> 9705084
# Created edge: 202090 -> 9705130
